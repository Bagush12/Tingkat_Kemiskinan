# %%
# Import Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import os
from scipy import stats
from sklearn.cluster import KMeans
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import pairwise_distances
from sklearn.metrics import silhouette_score

# %%
# Baca file excel ke dalam Pandas DataFrame
df = pd.read_excel('Kemiskinan di pulau jawa missing.xlsx')
df
# Out:
#     Kabupaten/Kota  Jumlah penduduk miskin (000)  Presentase penduduk miskin  \
# 0            Bogor                        474.74                        7.73
# 1         Sukabumi                        186.28                        7.34
# 2          Cianjur                        246.81                       10.55
# 3          Bandung                        258.61                        6.80
# 4            Garut                        276.67                       10.42
# ..             ...                           ...                         ...
# 95   Kota Pasuruan                         13.02                        6.37
# 96  Kota Mojokerto                          7.88                        5.98
# 97     Kota Madiun                          8.49                        4.76
# 98   Kota Surabaya                        138.21                        4.27
# 99       Kota Batu                          8.05                        3.79
#
#       P1    P2  Garis kemiskinan (Rp/Kap/Bulan)
# 0   1.49  0.45                         443787.0
# 1   0.93  0.19                         357636.0
# 2   1.35  0.27                         406829.0
# 3   0.90  0.21                         398884.0
# 4   1.81  0.45                         335134.0
# ..   ...   ...                              ...
# 95  0.93  0.22                         486893.0
# 96  0.87  0.18                         531804.0
# 97  0.40  0.06                         551620.0
# 98  0.69  0.18                         652540.0
# 99  0.64  0.16                         564010.0
#
# [100 rows x 6 columns]

# %%
# Tampilkan 5 baris pertama DataFrame
df.head()
# Out:
#   Kabupaten/Kota  Jumlah penduduk miskin (000)  Presentase penduduk miskin  \
# 0          Bogor                        474.74                        7.73
# 1       Sukabumi                        186.28                        7.34
# 2        Cianjur                        246.81                       10.55
# 3        Bandung                        258.61                        6.80
# 4          Garut                        276.67                       10.42
#
#      P1    P2  Garis kemiskinan (Rp/Kap/Bulan)
# 0  1.49  0.45                         443787.0
# 1  0.93  0.19                         357636.0
# 2  1.35  0.27                         406829.0
# 3  0.90  0.21                         398884.0
# 4  1.81  0.45                         335134.0

# %%
# Dapatkan jumlah baris dan kolom di DataFrame
df_shape = df.shape
print("Number of rows:", df_shape[0])
print("Number of columns:", df_shape[1])
# Out:
# Number of rows: 100
# Number of columns: 6

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
# Tampilkan informasi ringkasan tentang DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Kabupaten/Kota                   100 non-null    object
#  1   Jumlah penduduk miskin (000)     100 non-null    float64
#  2   Presentase penduduk miskin       99 non-null     float64
#  3   P1                               100 non-null    float64
#  4   P2                               99 non-null     float64
#  5   Garis kemiskinan (Rp/Kap/Bulan)  99 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 4.8+ KB

# %%
# Dapatkan ringkasan informasi statistik untuk setiap kolom numerik di DataFrame
df.describe().transpose()
# Out:
#                                  count           mean           std  \
# Jumlah penduduk miskin (000)     100.0     120.837300     78.062418
# Presentase penduduk miskin        99.0      10.009495      3.629716
# P1                               100.0       1.484400      0.664891
# P2                                99.0       0.349192      0.198359
# Garis kemiskinan (Rp/Kap/Bulan)   99.0  451347.898990  84780.918670
#
#                                        min          25%         50%  \
# Jumlah penduduk miskin (000)          7.88      73.8125     112.325
# Presentase penduduk miskin            2.53       7.3900       9.710
# P1                                    0.40       1.0150       1.345
# P2                                    0.06       0.2200       0.300
# Garis kemiskinan (Rp/Kap/Bulan)  327758.00  391183.0000  433864.000
#
#                                          75%        max
# Jumlah penduduk miskin (000)        157.3050     474.74
# Presentase penduduk miskin           12.0500      21.61
# P1                                    1.7625       3.72
# P2                                    0.4150       1.16
# Garis kemiskinan (Rp/Kap/Bulan)  499258.0000  744771.00

# %% [markdown]
# 1.1 Menghitung dan mencetak jumlah nilai yang hilang (missing values) dalam setiap kolom dari DataFrame

# %%
# cek nilai fitur yang hilang
print("\nJumlah nilai yang hilang:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang:
# Kabupaten/Kota                     0
# Jumlah penduduk miskin (000)       0
# Presentase penduduk miskin         1
# P1                                 0
# P2                                 1
# Garis kemiskinan (Rp/Kap/Bulan)    1
# dtype: int64

# %%
# Fungsi untuk mengisi data yang hilang dengan rata-rata
def isi_data_hilang_dengan_rata_rata(df):
    for kolom in df.columns:
        if pd.api.types.is_numeric_dtype(df[kolom].dtype):  # Cek tipe data kolom
            rata_rata = df[kolom].mean()
            df[kolom].fillna(rata_rata, inplace=True)

# %%
# Memanggil fungsi untuk mengisi data yang hilang dengan rata-rata
isi_data_hilang_dengan_rata_rata(df)

# Menampilkan DataFrame yang telah diisi
print(df)
# Out:
#     Kabupaten/Kota  Jumlah penduduk miskin (000)  Presentase penduduk miskin  \
# 0            Bogor                        474.74                        7.73
# 1         Sukabumi                        186.28                        7.34
# 2          Cianjur                        246.81                       10.55
# 3          Bandung                        258.61                        6.80
# 4            Garut                        276.67                       10.42
# ..             ...                           ...                         ...
# 95   Kota Pasuruan                         13.02                        6.37
# 96  Kota Mojokerto                          7.88                        5.98
# 97     Kota Madiun                          8.49                        4.76
# 98   Kota Surabaya                        138.21                        4.27
# 99       Kota Batu                          8.05                        3.79
#
#       P1    P2  Garis kemiskinan (Rp/Kap/Bulan)
# 0   1.49  0.45                         443787.0
# 1   0.93  0.19                         357636.0
# 2   1.35  0.27                         406829.0
# 3   0.90  0.21                         398884.0
# 4   1.81  0.45                         335134.0
# ..   ...   ...                              ...
# 95  0.93  0.22                         486893.0
# 96  0.87  0.18                         531804.0
# 97  0.40  0.06                         551620.0
# 98  0.69  0.18                         652540.0
# 99  0.64  0.16                         564010.0
#
# [100 rows x 6 columns]

# %%
# Mencetak hasil dari mengisi data yang hilang dengan rata-rata
print("\nJumlah nilai yang hilang:")
print(df.isnull().sum())
# Out:
# Jumlah nilai yang hilang:
# Kabupaten/Kota                     0
# Jumlah penduduk miskin (000)       0
# Presentase penduduk miskin         0
# P1                                 0
# P2                                 0
# Garis kemiskinan (Rp/Kap/Bulan)    0
# dtype: int64

# %% [markdown]
# # Rekayasa Fitur untuk Tingkat Kemiskinan di Pulau Jawa

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Korelasi antara Fitur Numerik')
plt.show()

# %%
# Membuat Visualisasi Distribusi Penduduk Miskin per Kabupaten/Kota
plt.figure(figsize=(15, 8))
plt.bar(df['Kabupaten/Kota'], df['Jumlah penduduk miskin (000)'])
plt.xticks(rotation=90)
plt.xlabel('Kabupaten/Kota')
plt.ylabel('Jumlah Penduduk Miskin (ribu)')
plt.title('Distribusi Penduduk Miskin per Kabupaten/Kota')
plt.tight_layout()
plt.show()

# %%
# Membuat Visualisasi Perbandingan Presentase Penduduk Miskin Dan Garis Kemiskinan per Kabupaten/Kota
plt.figure(figsize=(15, 8))
plt.plot(df['Kabupaten/Kota'], df['Presentase penduduk miskin'], marker='o', label='Presentase Penduduk Miskin')
plt.plot(df['Kabupaten/Kota'], df['Garis kemiskinan (Rp/Kap/Bulan)'], marker='o', label='Garis Kemiskinan')
plt.xticks(rotation=90)
plt.xlabel('Kabupaten/Kota')
plt.ylabel('Presentase / Garis Kemiskinan')
plt.title('Perbandingan Presentase Penduduk Miskin dan Garis Kemiskinan per Kabupaten/Kota')
plt.legend()
plt.tight_layout()
plt.show()

# %%
# Membuat Visualisasi Korelasi antara Presentase penduduk Miskin dan Garis Kemiskinan
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Presentase penduduk miskin', y='Garis kemiskinan (Rp/Kap/Bulan)')
plt.xlabel('Presentase Penduduk Miskin')
plt.ylabel('Garis Kemiskinan (Rp/Kap/Bulan)')
plt.title('Korelasi antara Presentase Penduduk Miskin dan Garis Kemiskinan')
plt.show()

# %%
# Menghitung nilai rata-rata (mean) dari tiga kolom dalam DataFrame
mean_miskin = df['Jumlah penduduk miskin (000)'].mean()
mean_presentase = df['Presentase penduduk miskin'].mean()
mean_garis = df['Garis kemiskinan (Rp/Kap/Bulan)'].mean()

# Menampilkan nilai rata-rata (mean) dari tiga kolom dalam DataFrame
print("Mean Jumlah Penduduk Miskin:", mean_miskin)
print("Mean Presentase Penduduk Miskin:", mean_presentase)
print("Mean Garis Kemiskinan:", mean_garis)
# Out:
# Mean Jumlah Penduduk Miskin: 120.83729999999994
# Mean Presentase Penduduk Miskin: 10.009494949494947
# Mean Garis Kemiskinan: 451347.898989899

# %%
# Menghitung nilai tengah (median) dari tiga kolom dalam DataFrame
median_miskin = df['Jumlah penduduk miskin (000)'].median()
median_presentase = df['Presentase penduduk miskin'].median()
median_garis = df['Garis kemiskinan (Rp/Kap/Bulan)'].median()

# Menampilkan nilai tengah (median) dari tiga kolom dalam DataFrame
print("Median Jumlah Penduduk Miskin:", median_miskin)
print("Median Presentase Penduduk Miskin:", median_presentase)
print("Median Garis Kemiskinan:", median_garis)
# Out:
# Median Jumlah Penduduk Miskin: 112.325
# Median Presentase Penduduk Miskin: 9.73
# Median Garis Kemiskinan: 434091.0

# %%
# Menghitung nilai yang paling banyak muncul(Modus) dari tiga kolom dalam DataFrame
modus_miskin = df['Jumlah penduduk miskin (000)'].mode()
modus_presentase = df['Presentase penduduk miskin'].mode()
modus_garis = df['Garis kemiskinan (Rp/Kap/Bulan)'].mode()

# Menampilkan nilai yang paling banyak muncul(Modus) dari tiga kolom dalam DataFrame
print("Modus Jumlah Penduduk Miskin:", modus_miskin[0])
print("Modus Presentase Penduduk Miskin:", modus_presentase[0])
print("Modus Garis Kemiskinan:", modus_garis[0])
# Out:
# Modus Jumlah Penduduk Miskin: 145.33
# Modus Presentase Penduduk Miskin: 4.25
# Modus Garis Kemiskinan: 371665.0

# %%
# Mengurutkan DataFrame df berdasarkan nilai dalam kolom 'Jumlah penduduk miskin (000)' secara menurun (descending order).
df_sorted = df.sort_values(by='Jumlah penduduk miskin (000)', ascending=False)

# Mengambil baris yang memiliki nilai tertinggi dalam kolom 'Jumlah penduduk miskin (000)' setelah DataFrame tersebut diurutkan secara menurun.
highest_poverty = df_sorted.iloc[0]

# Mengambil baris yang memiliki nilai terendah dalam kolom 'Jumlah penduduk miskin (000)' setelah DataFrame tersebut diurutkan secara menurun.
lowest_poverty = df_sorted.iloc[-1]

# %%
# Menampilkan Kota/Kabupaten dengan Tingkat Kemiskinan Tertinggi
print("Kota/Kabupaten dengan Tingkat Kemiskinan Tertinggi:")
print(highest_poverty)
# Out:
# Kota/Kabupaten dengan Tingkat Kemiskinan Tertinggi:
# Kabupaten/Kota                        Bogor
# Jumlah penduduk miskin (000)         474.74
# Presentase penduduk miskin             7.73
# P1                                     1.49
# P2                                     0.45
# Garis kemiskinan (Rp/Kap/Bulan)    443787.0
# Name: 0, dtype: object

# %%
# Menampilkan Kota/Kabupaten dengan Tingkat Kemiskinan Terendah
print("\nKota/Kabupaten dengan Tingkat Kemiskinan Terendah:")
print(lowest_poverty)
# Out:
# Kota/Kabupaten dengan Tingkat Kemiskinan Terendah:
# Kabupaten/Kota                     Kota Mojokerto
# Jumlah penduduk miskin (000)                 7.88
# Presentase penduduk miskin                   5.98
# P1                                           0.87
# P2                                           0.18
# Garis kemiskinan (Rp/Kap/Bulan)          531804.0
# Name: 96, dtype: object

# %%
# Mengganti karakter koma (,) dengan titik (.) dalam kolom-kolom numerik dalam DataFrame df dan mengubah kolom-kolom tersebut menjadi tipe data numerik.
df.replace({',': '.'}, regex=True, inplace=True)
numeric_columns = df.columns[1:]  # Kolom numerik kecuali 'Kabupaten/Kota'
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)

# Menghapus baris (row) yang mengandung setidaknya satu nilai yang hilang (NaN, Not-a-Number) dari DataFrame
df.dropna(inplace=True)

# Mengambil subset dari DataFrame df yang hanya terdiri dari kolom-kolom numerik
X = df[numeric_columns]

# Mengisi nilai NaN dengan nilai median untuk kolom tertentu
columns_to_fill = ['Jumlah penduduk miskin (000)', 'Presentase penduduk miskin']
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].median())

# %% [markdown]
# # Metode Elbow untuk Tingkat Kemiskinan di Pulau Jawa

# %%
# mengambil nilai dari kolom 'Jumlah penduduk miskin (000)
X = df[['Jumlah penduduk miskin (000)']].values

# membuat sebuah list (daftar) dengan nama wcss
wcss = []

# menghitung nilai Within-Cluster Sum of Squares (WCSS) untuk berbagai jumlah cluster (dari 1 hingga 10).
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\Mazguz\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
# membuat sebuah grafik yang menampilkan hasil dari metode elbow (siku) dalam menentukan jumlah cluster yang optimal dalam analisis K-Means.
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='-', color='b')
plt.title('Metode Elbow')
plt.xlabel('Jumlah Cluster')
plt.ylabel('WCSS (Within-cluster sum of squares)')
plt.grid(True)
plt.show()

# %%
# Mengambil subset dari DataFrame df yang terdiri dari kolom-kolom numerik dan menyimpannya dalam variabel X
X = df[numeric_columns]

# Melakukan penskalaan (scaling) data dalam variabel X menggunakan teknik StandardScaler dari pustaka scikit-learn (sklearn).
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# pengaturan nilai yang menentukan jumlah kluster yang akan digunakan dalam algoritma K-Means
n_clusters = 4

# Membuat objek SimpleImputer untuk menggantikan NaN dengan mean
imputer = SimpleImputer(strategy='mean')

# Mengisi nilai-nilai NaN dalam dataset dengan mean
X_imputed = imputer.fit_transform(X)

# %% [markdown]
# # Algortima Machine Learning Untuk Tingkat Kemiskinan di Pulau Jawa

# %%
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(X_imputed)

# mencetak atau menampilkan dua kolom dari DataFrame df, yaitu 'Kabupaten/Kota' dan 'Cluster'
print(df[['Kabupaten/Kota', 'Cluster']])
# Out:
#     Kabupaten/Kota  Cluster
# 0            Bogor        0
# 1         Sukabumi        2
# 2          Cianjur        2
# 3          Bandung        2
# 4            Garut        2
# ..             ...      ...
# 95   Kota Pasuruan        0
# 96  Kota Mojokerto        1
# 97     Kota Madiun        1
# 98   Kota Surabaya        3
# 99       Kota Batu        1
#
# [100 rows x 2 columns]

# %%
# Menampilkan semua baris
print(df[['Kabupaten/Kota', 'Cluster']])
import pandas as pd
pd.set_option('display.max_rows', None)
# Out:
#     Kabupaten/Kota  Cluster
# 0            Bogor        0
# 1         Sukabumi        2
# 2          Cianjur        2
# 3          Bandung        2
# 4            Garut        2
# ..             ...      ...
# 95   Kota Pasuruan        0
# 96  Kota Mojokerto        1
# 97     Kota Madiun        1
# 98   Kota Surabaya        3
# 99       Kota Batu        1
#
# [100 rows x 2 columns]

# %%
print(df[['Kabupaten/Kota', 'Cluster']])
import pandas as pd
pd.set_option('display.max_rows', None)  # Menampilkan semua baris

print(df)
# Out:
#       Kabupaten/Kota  Cluster
# 0              Bogor        0
# 1           Sukabumi        2
# 2            Cianjur        2
# 3            Bandung        2
# 4              Garut        2
# 5        Tasikmalaya        2
# 6             Ciamis        0
# 7           Kuningan        2
# 8            Cirebon        2
# 9         Majalengka        0
# 10          Sumedang        2
# 11         Indramayu        0
# 12            Subang        2
# 13        Purwakarta        2
# 14          Karawang        1
# 15            Bekasi        1
# 16     Bandung Barat        2
# 17       Pangandaran        2
# 18        Kota Bogor        1
# 19     Kota Sukabumi        1
# 20      Kota Bandung        1
# 21      Kota Cirebon        0
# 22       Kota Bekasi        3
# 23        Kota Depok        3
# 24       Kota Cimahi        1
# 25  Kota Tasikmalaya        0
# 26       Kota Banjar        2
# 27           Cilacap        2
# 28          Banyumas        0
# 29       Purbalingga        2
# 30     Banjar negara        2
# 31           Kebumen        2
# 32         Purworejo        2
# 33          Wonosobo        2
# 34          Magelang        2
# 35          Boyolali        2
# 36            Klaten        0
# 37         Sukoharjo        0
# 38          Wonogiri        2
# 39       Karanganyar        0
# 40            Sragen        2
# 41          Grobogan        0
# 42             Blora        2
# 43           Rembang        0
# 44              Pati        0
# 45             Kudus        0
# 46            Jepara        0
# 47             Demak        0
# 48          Semarang        0
# 49        Temanggung        2
# 50            Kendal        0
# 51            Batang        2
# 52        Pekalongan        0
# 53          Pemalang        0
# 54             Tegal        0
# 55            Brebes        0
# 56     Kota Magelang        1
# 57    Kota Surakarta        1
# 58     Kota Salatiga        1
# 59     Kota Semarang        1
# 60   Kota Pekalongan        1
# 61        Kota Tegal        1
# 62           Pacitan        2
# 63          Ponorogo        2
# 38                     376763.00000        2
# 39                     424677.00000        0
# 40                     389265.00000        2
# 41                     428597.00000        0
# 42                     390478.00000        2
# 43                     441482.00000        0
# 44                     486855.00000        0
# 45                     482806.00000        0
# 46                     442618.00000        0
# 47                     471818.00000        0
# 48                     459151.00000        0
# 49                     354012.00000        2
# 50                     433864.00000        0
# 51                     341252.00000        2
# 52                     441765.00000        0
# 53                     429549.00000        0
# 54                     434638.00000        0
# 55                     472326.00000        0
# 56                     575130.00000        1
# 57                     538441.00000        1
# 58                     518815.00000        1
# 59                     589598.00000        1
# 60                     513243.00000        1
# 61                     565826.00000        1
# 62                     327758.00000        2
# 63                     362461.00000        2
# 64                     381448.00000        2
# 65                     391888.00000        2
# 66                     355511.00000        2
# 67                     353033.00000        2
# 68                     367579.00000        2
# 69                     352776.00000        2
# 70                     400961.00000        2
# 71                     414879.00000        2
# 72                     449760.00000        0
# 73                     356133.00000        2
# 74                     475713.00000        0
# 75                     394016.00000        2
# 76                     523213.00000        1
# 77                     445608.00000        0
# 78                     448830.00000        0
# 79                     474429.00000        0
# 80                     405127.00000        2
# 81                     396696.00000        2
# 82                     382301.00000        2
# 83                     403403.00000        2
# 84                     421287.00000        0
# 85                     446601.00000        0
# 86                     536544.00000        1
# 87                     458754.00000        0
# 88                     411661.00000        2
# 89                     392345.00000        2
# 90                     427882.00000        0
# 91                     537326.00000        1
# 92                     517363.00000        1
# 93                     609612.00000        1
# 94                     575195.00000        1
# 95                     486893.00000        0
# 96                     531804.00000        1
# 97                     551620.00000        1
# 98                     652540.00000        3
# 99                     564010.00000        1

# %% [markdown]
# # Visualisasi Hasil Clustering

# %%
# Mengisi nilai NaN dengan nilai median untuk kolom tertentu
columns_to_fill = ['Jumlah penduduk miskin (000)', 'Presentase penduduk miskin']
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].median())

# Standarisasi fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Jumlah cluster yang diinginkan
n_clusters = 4

# %% [markdown]
# 5.1 Melakukan clustering dengan K-Means

# %%
#Menambahkan kolom cluster ke data asli
kmeans = KMeans(n_clusters=n_clusters, random_state=0)
clusters = kmeans.fit_predict(X_scaled)

df['Cluster'] = clusters

# %% [markdown]
# 5.2 Visualisasi hasil clustering

# %%
plt.figure(figsize=(12, 8))
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Jumlah penduduk miskin (000)')
plt.ylabel('Presentase penduduk miskin')
plt.title(f'Clustering Data Penduduk Miskin (Jumlah Cluster = {n_clusters})')
plt.colorbar(label='Cluster')
plt.show()

# %% [markdown]
# # Menghitung jarak data ke setiap pusat cluster

# %%
# Menyimpan nama kota dalam DataFrame
kota = df['Kabupaten/Kota']

# Memilih fitur yang akan digunakan untuk clustering
X = df[['Jumlah penduduk miskin (000)', 'Presentase penduduk miskin']]

# Menghitung jarak data ke setiap pusat cluster
distances = pairwise_distances(X_scaled, kmeans.cluster_centers_)

# Membuat DataFrame dengan keterangan nama kota dan matriks jarak
distance_df = pd.DataFrame(distances, columns=[f'Cluster_{i+1}' for i in range(n_clusters)])
distance_df.insert(0, 'Kabupaten/Kota', kota)

# Menampilkan DataFrame dengan keterangan
print("Matrix Jarak dengan Nama Kota:")
print(distance_df)
# Out:
# 90           Sumenep   2.618066   7.856861   6.644320   5.346973
# 91       kota Kediri   4.348748   1.506555   2.037694   2.895916
# 92       Kota Blitar   5.287248   0.923944   1.863372   3.256152
# 93       Kota Malang   5.445311   0.998616   2.905265   3.801676
# 94  Kota Probolinggo   5.288005   0.602620   2.366073   3.492437
# 95     Kota Pasuruan   5.262173   1.135910   1.676395   3.157725
# 96    Kota Mojokerto   5.569970   0.758304   2.162458   3.535994
# 97       Kota Madiun   6.494342   1.234985   2.892264   4.290145
# 98     Kota Surabaya   5.996927   1.568922   3.440467   4.057404
# 99         Kota Batu   6.206000   0.946921   2.839471   4.154306

# %%
# Menghitung jarak antara setiap data dengan pusat cluster terdekat
distances = kmeans.transform(X_scaled)  # Menggunakan transform untuk menghitung jarak

# Membuat DataFrame dengan keterangan nama kota dan jarak ke pusat cluster terdekat
distance_df = pd.DataFrame(distances, columns=[f'Jarak ke Cluster {i+1}' for i in range(n_clusters)])
distance_df.insert(0, 'Kabupaten/Kota', df['Kabupaten/Kota'])

#Menampilkan DataFrame dengan jarak ke pusat cluster terdekat
print("Jarak ke Pusat Cluster Terdekat:")
print(distance_df)
# Out:
# Jarak ke Pusat Cluster Terdekat:
#       Kabupaten/Kota  Jarak ke Cluster 1  Jarak ke Cluster 2  \
# 0              Bogor            5.143086            5.862389
# 1           Sukabumi            4.857343            3.079643
# 2            Cianjur            3.800413            3.496937
# 3            Bandung            4.925458            3.343871
# 4              Garut            3.270615            4.608135
# 5        Tasikmalaya            3.748728            3.588429
# 6             Ciamis            4.529775            1.623923
# 7           Kuningan            2.082270            4.108102
# 8            Cirebon            2.032057            4.692855
# 9         Majalengka            3.064685            2.637722
# 10          Sumedang            2.669115            3.644984
# 11         Indramayu            2.508906            3.573427
# 12            Subang            3.291805            3.248120
# 13        Purwakarta            4.327845            2.225169
# 14          Karawang            3.462203            2.576041
# 15            Bekasi            4.877978            2.209644
# 16     Bandung Barat            2.925180            3.423612
# 17       Pangandaran            4.371529            2.212126
# 18        Kota Bogor            4.761299            0.996979
# 19     Kota Sukabumi            4.586015            1.305057
# 20      Kota Bandung            5.671556            0.969084
# 21      Kota Cirebon            4.148660            1.728509
# 22       Kota Bekasi            6.016269            2.276362
# 23        Kota Depok            7.291713            2.450297
# 24       Kota Cimahi            5.897990            0.629953
# 25  Kota Tasikmalaya            1.857802            3.817309
# 26       Kota Banjar            5.044959            2.454458
# 27           Cilacap            3.384139            3.346889
# 28          Banyumas            2.824795            3.596879
# 29       Purbalingga            1.913951            4.146523
# 30     Banjar negara            2.031663            4.647820
# 31           Kebumen            1.689512            6.874866
# 32         Purworejo            3.956175            2.722656
# 33          Wonosobo            1.172850            6.045143
# 34          Magelang            3.003471            3.351121
# 35          Boyolali            4.391141            2.564578
# 36            Klaten            2.445724            3.156541
# 37         Sukoharjo            5.110818            1.721361
# 38          Wonogiri            3.785432            2.892616
# 39       Karanganyar            3.390797            2.542412
# 17            0.663683            2.213831
# 18            2.498209            3.126842
# 19            2.477919            3.226501
# 20            2.384431            3.366413
# 21            1.237489            2.341510
# 22            4.171702            4.555946
# 23            4.706195            5.546532
# 24            2.441925            3.748203
# 25            2.958413            2.327384
# 26            1.315962            2.873406
# 27            1.500219            0.590957
# 28            2.192887            0.751661
# 29            2.481777            1.362231
# 30            2.749987            1.704283
# 31            5.603841            4.313386
# 32            0.675808            1.652597
# 33            4.661049            3.569274
# 34            1.358087            0.642121
# 35            0.498245            1.824386
# 36            1.819731            0.877805
# 37            1.055204            2.606091
# 38            0.657575            1.348168
# 39            0.850645            1.339332
# 40            1.717002            1.158038
# 41            1.874739            0.585981
# 42            1.337276            1.121366
# 43            2.880155            2.084238
# 44            1.037908            1.764164
# 45            1.266360            2.645725
# 46            0.811968            2.028744
# 47            1.530972            0.964650
# 48            0.937875            2.337812
# 49            0.805332            2.213235
# 50            0.836326            1.369104
# 51            0.824179            2.013492
# 52            1.149136            1.415881
# 53            3.195646            1.740510
# 54            0.886585            2.138861
# 55            4.476127            2.870495
# 56            2.819559            4.122810
# 57            1.698533            2.732973
# 58            2.358679            3.800187
# 59            2.902709            3.961124
# 60            1.811066            3.213538
# 61            2.142801            3.172909
# 62            1.598165            2.059057
# 63            0.842114            2.243561
# 64            0.621294            1.622984
# 65            1.467999            2.984952
# 66            0.678508            1.641666
# 67            1.606689            0.734708
# 68            2.254891            1.988481
# 69            0.696357            1.651344
# 70            1.879971            1.567723
# 71            0.662372            1.755132
# 72            1.459826            1.299057
# 73            0.938434            1.692259
# 74            3.772029            2.384718
# 75            0.796314            1.199175
# 76            1.975412            2.882446
# 77            0.609404            1.374022
# 78            0.645100            1.678280
# 79            1.052515            1.343177
# 80            0.961334            1.438774
# 81            0.718922            1.679686
# 82            1.592421            1.237159
# 83            1.679682            0.526566
# 84            4.222266            2.935508
# 85            2.307270            1.157051
# 86            3.922860            3.063423
# 87            4.812314            3.473381
# 88            4.746345            3.415909
# 89            1.994912            1.145734
# 90            6.644320            5.346973
# 91            2.037694            2.895916
# 92            1.863372            3.256152
# 93            2.905265            3.801676
# 94            2.366073            3.492437
# 95            1.676395            3.157725
# 96            2.162458            3.535994
# 97            2.892264            4.290145
# 98            3.440467            4.057404
# 99            2.839471            4.154306

# %%
# Range jumlah cluster yang akan diuji
range_clusters = range(2, 11)  # Ubah dari 1 menjadi 2 cluster

# Menyimpan Silhouette Score untuk setiap jumlah cluster
silhouette_scores = []

for n_clusters in range_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    cluster_labels = kmeans.fit_predict(X_scaled)
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)
    silhouette_scores.append(silhouette_avg)

# Plot grafik Silhouette Score
plt.figure(figsize=(8, 6))
plt.plot(range_clusters, silhouette_scores, marker='o', linestyle='-')
plt.xlabel('Jumlah Cluster')
plt.ylabel('Silhouette Score')
plt.title('Metode Silhouette Score untuk Menentukan Jumlah Cluster Optimal')
plt.grid(True)
plt.show()
